# %%
import pandas as pd

covid = pd.read_csv('/work/SQL-Journey/CovidDeaths.csv')
vaccines = pd.read_csv('/work/Vaccines.csv')

# %%
df = _deepnote_execute_sql("""SELECT *
FROM covid
LIMIT 5

""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
#
#   new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 0               None         None       None                None  ...
# 1               None         None       None                None  ...
# 2               None         None       None                None  ...
# 3               None         None       None                None  ...
# 4               None         None       None                None  ...
#
#    gdp_per_capita  extreme_poverty cardiovasc_death_rate diabetes_prevalence  \
# ...

# %%
df_2 = _deepnote_execute_sql("""SELECT *
FROM covid
WHERE continent IS NOT null 
ORDER BY 3,4;
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_2
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan   1/1/2021      51526.0        0.0
# 1          AFG      Asia  Afghanistan  1/10/2021      53489.0       89.0
# 2          AFG      Asia  Afghanistan  1/11/2021      53538.0       49.0
# 3          AFG      Asia  Afghanistan  1/12/2021      53584.0       46.0
# 4          AFG      Asia  Afghanistan  1/13/2021      53584.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 81055      ZWE    Africa     Zimbabwe   9/5/2020       6837.0        0.0
# 81056      ZWE    Africa     Zimbabwe   9/6/2020       6837.0        0.0
# 81057      ZWE    Africa     Zimbabwe   9/7/2020       7298.0      461.0
# 81058      ZWE    Africa     Zimbabwe   9/8/2020       7388.0       90.0
# 81059      ZWE    Africa     Zimbabwe   9/9/2020       7429.0       41.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# Let's select the data we are going to be starting with

# %%
df_3 = _deepnote_execute_sql("""SELECT location, date, total_cases, new_cases, total_deaths, population
FROM covid
    Where continent IS NOT null 
        ORDER BY 1,2
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_3
# Out:
#           location       date  total_cases  new_cases  total_deaths  \
# 0      Afghanistan   1/1/2021      51526.0        0.0        2191.0
# 1      Afghanistan  1/10/2021      53489.0       89.0        2277.0
# 2      Afghanistan  1/11/2021      53538.0       49.0        2288.0
# 3      Afghanistan  1/12/2021      53584.0       46.0        2301.0
# 4      Afghanistan  1/13/2021      53584.0        0.0        2301.0
# ...            ...        ...          ...        ...           ...
# 81055     Zimbabwe   9/5/2020       6837.0        0.0         206.0
# 81056     Zimbabwe   9/6/2020       6837.0        0.0         206.0
# 81057     Zimbabwe   9/7/2020       7298.0      461.0         210.0
# 81058     Zimbabwe   9/8/2020       7388.0       90.0         218.0
# 81059     Zimbabwe   9/9/2020       7429.0       41.0         222.0
#
#        population
# 0      38928341.0
# 1      38928341.0
# 2      38928341.0
# 3      38928341.0
# 4      38928341.0
# ...           ...
# ...

# %% [markdown]
# Here we will make a comparasion of Total cases vs Total Deaths, the idea is to show the likelihood of dying if you get covid in your country, let's use 'Colombia' as an example.

# %%
df_4 = _deepnote_execute_sql("""SELECT location, date, total_cases,total_deaths, ROUND((total_deaths/total_cases)*100,2) AS DeathPercentage
FROM covid
WHERE location = 'Colombia'
      AND continent IS NOT null 
ORDER BY 2 DESC;

""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_4
# Out:
#      location       date  total_cases  total_deaths  DeathPercentage
# 0    Colombia   9/9/2020     686851.0       22053.0             3.21
# 1    Colombia   9/8/2020     679513.0       21817.0             3.21
# 2    Colombia   9/7/2020     671848.0       21615.0             3.22
# 3    Colombia   9/6/2020     666521.0       21412.0             3.21
# 4    Colombia   9/5/2020     658456.0       21156.0             3.21
# ..        ...        ...          ...           ...              ...
# 416  Colombia  1/13/2021    1831980.0       47124.0             2.57
# 417  Colombia  1/12/2021    1816082.0       46782.0             2.58
# 418  Colombia  1/11/2021    1801903.0       46451.0             2.58
# 419  Colombia  1/10/2021    1786900.0       46114.0             2.58
# 420  Colombia   1/1/2021    1654880.0       43495.0             2.63
#
# [421 rows x 5 columns]

# %% [markdown]
# Now let's make the same exercise but with population, Cases Vs Population

# %%
df_5 = _deepnote_execute_sql("""SELECT location, date, Population, total_cases,  ROUND((total_cases/population)*100,2) as Percent_PopulationInfected
FROM covid
    WHERE location = 'Colombia'
        ORDER BY 2 DESC;
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_5
# Out:
#      location       date  population  total_cases  Percent_PopulationInfected
# 0    Colombia   9/9/2020  50882884.0     686851.0                        1.35
# 1    Colombia   9/8/2020  50882884.0     679513.0                        1.34
# 2    Colombia   9/7/2020  50882884.0     671848.0                        1.32
# 3    Colombia   9/6/2020  50882884.0     666521.0                        1.31
# 4    Colombia   9/5/2020  50882884.0     658456.0                        1.29
# ..        ...        ...         ...          ...                         ...
# 416  Colombia  1/13/2021  50882884.0    1831980.0                        3.60
# 417  Colombia  1/12/2021  50882884.0    1816082.0                        3.57
# 418  Colombia  1/11/2021  50882884.0    1801903.0                        3.54
# 419  Colombia  1/10/2021  50882884.0    1786900.0                        3.51
# 420  Colombia   1/1/2021  50882884.0    1654880.0                        3.25
#
# [421 rows x 5 columns]

# %%
df_6 = _deepnote_execute_sql("""SELECT location, date, Population, total_cases,  ROUND((total_cases/population)*100,2) as Percent_PopulationInfected
FROM covid
    WHERE location = 'Colombia'
        ORDER BY 2 DESC;
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_6
# Out:
#      location       date  population  total_cases  Percent_PopulationInfected
# 0    Colombia   9/9/2020  50882884.0     686851.0                        1.35
# 1    Colombia   9/8/2020  50882884.0     679513.0                        1.34
# 2    Colombia   9/7/2020  50882884.0     671848.0                        1.32
# 3    Colombia   9/6/2020  50882884.0     666521.0                        1.31
# 4    Colombia   9/5/2020  50882884.0     658456.0                        1.29
# ..        ...        ...         ...          ...                         ...
# 416  Colombia  1/13/2021  50882884.0    1831980.0                        3.60
# 417  Colombia  1/12/2021  50882884.0    1816082.0                        3.57
# 418  Colombia  1/11/2021  50882884.0    1801903.0                        3.54
# 419  Colombia  1/10/2021  50882884.0    1786900.0                        3.51
# 420  Colombia   1/1/2021  50882884.0    1654880.0                        3.25
#
# [421 rows x 5 columns]

# %% [markdown]
# Let's make a quick Viz on how this percentage increased over time.

# %%
DeepnoteChart(df_6, """{"mark":{"type":"bar","tooltip":true},"$schema":"https://vega.github.io/schema/vega-lite/v4.json","encoding":{"x":{"sort":null,"type":"temporal","field":"date","scale":{"type":"linear","zero":false}},"y":{"bin":false,"sort":null,"type":"quantitative","field":"Percent_PopulationInfected","scale":{"type":"linear","zero":true}},"color":{"sort":null,"type":"quantitative","field":"total_cases","scale":{"type":"linear","zero":false}}},"height":440,"width":"container","autosize":{"type":"fit"},"config":{"legend":{"labelFont":"Inter, sans-serif","labelFontSize":12,"titleFont":"Inter, sans-serif","titleFontSize":12,"titleFontWeight":"bold"},"title":{"anchor":"start","color":"#000000","font":"Inter, sans-serif","fontSize":22,"fontWeight":"normal"},"axis":{"labelFont":"Inter, sans-serif","labelFontSize":12,"labelFontWeight":"normal","titleFont":"Inter, sans-serif","titleFontSize":12,"titleFontWeight":"bold","labelOverlap":"greedy"}}}""")

# %% [markdown]
# Countries with Highest Infection Rate compared to Population

# %%
df_7 = _deepnote_execute_sql("""SELECT  location, 
        Population, 
        MAX(total_cases) as HighestInfectionCount,  
        ROUND(MAX((total_cases/population))*100,2) AS Percent_PopulationInfected

FROM covid
    GROUP BY Location, Population
        HAVING Percent_PopulationInfected != 'nan'
ORDER BY Percent_PopulationInfected DESC;
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_7
# Out:
#                  location  population  HighestInfectionCount  \
# 0                 Andorra     77265.0                13232.0
# 1              Montenegro    628062.0                97389.0
# 2                 Czechia  10708982.0              1630758.0
# 3              San Marino     33938.0                 5066.0
# 4                Slovenia   2078932.0               240292.0
# ..                    ...         ...                    ...
# 193              Tanzania  59734213.0                  509.0
# 194               Vanuatu    307150.0                    4.0
# 195               Vietnam  97338583.0                 2928.0
# 196                Taiwan  23816775.0                 1128.0
# 197  Micronesia (country)    115021.0                    1.0
#
#      Percent_PopulationInfected
# 0                         17.13
# 1                         15.51
# 2                         15.23
# 3                         14.93
# 4                         11.56
# ..                          ...
# ...

# %% [markdown]
# Now i want to know the countries with the highest death count per population

# %%
df_8 = _deepnote_execute_sql("""SELECT location, MAX(cast(Total_deaths as int)) AS TotalDeathCount
From covid

WHERE continent IS NOT null  
    GROUP BY location
        ORDER BY TotalDeathCount DESC
        OFFSET 28;  --if you don't want to exclude the values you can skip them with this.
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_8
# Out:
#            location  TotalDeathCount
# 0     United States           576232
# 1            Brazil           403781
# 2            Mexico           216907
# 3             India           211853
# 4    United Kingdom           127775
# ..              ...              ...
# 177          Brunei                3
# 178            Fiji                2
# 179         Vanuatu                1
# 180          Bhutan                1
# 181         Grenada                1
#
# [182 rows x 2 columns]

# %% [markdown]
# Now let's do the same thing but i want to break it down by continent

# %%
df_9 = _deepnote_execute_sql("""SELECT continent, MAX(cast(Total_deaths as int)) AS TotalDeathCount
FROM covid

WHERE continent IS NOT null  
    GROUP BY continent
        ORDER BY TotalDeathCount DESC;

-- Yeah yeah...i know, i'm also bothered that this dataset states that america has 2 continents.

""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_9
# Out:
#        continent  TotalDeathCount
# 0  North America           576232
# 1  South America           403781
# 2           Asia           211853
# 3         Europe           127775
# 4         Africa            54350
# 5        Oceania              910

# %% [markdown]
# -- Total Population vs Vaccinations
# -- Shows Percentage of Population that has recieved at least one Covid Vaccine

# %%
df_10 = _deepnote_execute_sql("""SELECT a.continent, 
        a.location, 
        a.date, 
        a.population, 
        vac.new_Vaccinations,
        SUM(vac.new_vaccinations) OVER (Partition by a.Location ORDER BY a.location, a.date) AS RollingPeopleVaccinated,
        --(RollingPeopleVaccinated/population)*100 AS percentig
FROM covid AS a
    JOIN vaccines AS vac ON a.location = vac.location
	AND a.date = vac.date

WHERE a.continent IS NOT null 
ORDER BY 2,3, RollingPeopleVaccinated DESC;

""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_10
# Out:
#       continent     location       date  population  new_vaccinations  \
# 0          Asia  Afghanistan   1/1/2021  38928341.0               NaN
# 1          Asia  Afghanistan  1/10/2021  38928341.0               NaN
# 2          Asia  Afghanistan  1/11/2021  38928341.0               NaN
# 3          Asia  Afghanistan  1/12/2021  38928341.0               NaN
# 4          Asia  Afghanistan  1/13/2021  38928341.0               NaN
# ...         ...          ...        ...         ...               ...
# 81055    Africa     Zimbabwe   9/5/2020  14862927.0               NaN
# 81056    Africa     Zimbabwe   9/6/2020  14862927.0               NaN
# 81057    Africa     Zimbabwe   9/7/2020  14862927.0               NaN
# 81058    Africa     Zimbabwe   9/8/2020  14862927.0               NaN
# 81059    Africa     Zimbabwe   9/9/2020  14862927.0               NaN
#
#        RollingPeopleVaccinated
# 0                          NaN
# 1                          NaN
# ...

# %% [markdown]
# Here we use a CTE to perform a calculation from the previous query

# %%
df_11 = _deepnote_execute_sql("""--Using CTE to perform Calculation on Partition By in previous query

With PopvsVac (Continent, Location, Date, Population, New_Vaccinations, RollingPeopleVaccinated)
as
(
Select a.continent, a.location, a.date, a.population, vac.new_vaccinations
, SUM(CONVERT(int,vac.new_vaccinations)) OVER (Partition by a.Location Order by a.location, a.Date) as RollingPeopleVaccinated
--, (RollingPeopleVaccinated/population)*100
From covid AS a
Join vaccines AS vac
	On a.location = vac.location
	and a.date = vac.date
where a.continent is not null 
--order by 2,3
)
Select *, (RollingPeopleVaccinated/Population)*100
From PopvsVac
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_11
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df_11 = _deepnote_execute_sql("""--Using CTE to perform Calculation on Partition By in previous query
#       2
#       3 With PopvsVac (Continent, Location, Date, Population, New_Vaccinations, RollingPeopleVaccinated)
#       4 as
#       5 (
#       6 Select a.continent, a.location, a.date, a.population, vac.new_vaccinations
#       7 , SUM(CONVERT(int,vac.new_vaccinations)) OVER (Partition by a.Location Order by a.location, a.Date) as RollingPeopleVaccinated
#       8 --, (RollingPeopleVaccinated/population)*100
#       9 From covid AS a
#      10 Join vaccines AS vac
#      11 	On a.location = vac.location
#      12 	and a.date = vac.date
#      13 where a.continent is not null
#      14 --order by 2,3
#      15 )
#      16 Select *, (RollingPeopleVaccinated/Population)*100
# ...

# %% [markdown]
# Now let´s just create a view to store data for later visualizations

# %%
df_12 = _deepnote_execute_sql("""Create View PercentPopulationVaccinated as
Select dea.continent, dea.location, dea.date, dea.population, vac.new_vaccinations
, SUM(CONVERT(int,vac.new_vaccinations)) OVER (Partition by dea.Location Order by dea.location, dea.Date) as RollingPeopleVaccinated
--, (RollingPeopleVaccinated/population)*100
From covid AS dea
Join Vaccines AS vac
	On dea.location = vac.location
	and dea.date = vac.date
where dea.continent is not null 
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_12
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 df_12 = _deepnote_execute_sql("""Create View PercentPopulationVaccinated as
#       2 Select dea.continent, dea.location, dea.date, dea.population, vac.new_vaccinations
#       3 , SUM(CONVERT(int,vac.new_vaccinations)) OVER (Partition by dea.Location Order by dea.location, dea.Date) as RollingPeopleVaccinated
#       4 --, (RollingPeopleVaccinated/population)*100
#       5 From covid AS dea
#       6 Join Vaccines AS vac
#       7 	On dea.location = vac.location
#       8 	and dea.date = vac.date
#       9 where dea.continent is not null
#      10 """, 'SQL_DEEPNOTE_DATAFRAME_SQL')
#      11 df_12
#
# File /compute-helpers/code/sql_utils.py:50, in _deepnote_execute_sql(template, sql_alchemy_json_env_var)
#      47 engine = create_engine(sql_alchemy_dict["url"], **sql_alchemy_dict["params"])
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b7bc86a8-ee30-4379-a9c0-38c2f753b7b6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
